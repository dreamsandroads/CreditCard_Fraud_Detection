# %%
import dask.dataframe as dd

# %%
import pandas as pd

# %%
df_cct = dd.read_csv("D:\Statapp\data\credit_card_transactions-ibm_v2.csv", dtype='str')

# %%
df = df_cct.get_partition(69)
df["Half_amount"] = df["Amount"].str[:5]

# %%
df.compute()
# Out:
#         User Card  Year Month Day   Time   Amount            Use Chip  \
# 0       1965    0  2014     8   9  23:33   $22.39  Online Transaction
# 1       1965    0  2014     8  11  06:48   $34.54  Online Transaction
# 2       1965    0  2014     8  11  10:43   $23.25   Swipe Transaction
# 3       1965    0  2014     8  12  06:06   $55.77   Swipe Transaction
# 4       1965    0  2014     8  12  06:07   $88.00   Swipe Transaction
# ...      ...  ...   ...   ...  ..    ...      ...                 ...
# 344313  1999    1  2020     2  27  22:23  $-54.00    Chip Transaction
# 344314  1999    1  2020     2  27  22:24   $54.00    Chip Transaction
# 344315  1999    1  2020     2  28  07:43   $59.15    Chip Transaction
# 344316  1999    1  2020     2  28  20:10   $43.12    Chip Transaction
# 344317  1999    1  2020     2  28  23:10   $45.13    Chip Transaction
#
#                Merchant Name   Merchant City Merchant State      Zip   MCC  \
# ...

# %%
df.to_parquet(r"D:\Statapp\Lisa\test.parquet")

# %%
df.to_csv(r"D:\Statapp\Lisa\test.csv")
# Out:
# ['D:\\Statapp\\Lisa\\test.csv\\0.part']

# %%
df.drop_duplicates()
print(len(df))
# Out:
# 344318
